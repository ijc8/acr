# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3])

# %%
import numpy as np
plt.scatter(np.random.normal(size=1000), np.random.normal(size=1000))

# %%
import scipy.signal
scipy.signal.convolve([0,1,2,3,4,5,6,7], [1, 1])
# Out:
# array([ 0,  1,  3,  5,  7,  9, 11, 13,  7])
